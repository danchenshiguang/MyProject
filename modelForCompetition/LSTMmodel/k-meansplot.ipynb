# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import os

# %%
os.chdir("D:\学习材料\数学\数学建模与实验\美赛\美赛进行时\\2023\\2023_MCM-ICM_Problems")

# %%
df=pd.read_excel("./333/c.xlsx")

# %%
df
# Out:
#           Date  Contest number   Word  Number of  reported results  \
# 0   2022-01-07             202  slump                        80630
# 1   2022-01-08             203  crank                       101503
# 2   2022-01-09             204  gorge                        91477
# 3   2022-01-10             205  query                       107134
# 4   2022-01-11             206  drink                       153880
# ..         ...             ...    ...                          ...
# 354 2022-12-27             556  condo                        20879
# 355 2022-12-28             557  impel                        20160
# 356 2022-12-29             558  havoc                        20001
# 357 2022-12-30             559  molar                        21204
# 358 2022-12-31             560  manly                        20380
#
#      Number in hard mode     1 try   2 tries    3 tries    4 tries    5 tries  \
# 0                   1362  1.000000  3.000000  23.000000  39.000000  24.000000
# ...

# %%
plt.scatter(x=df['Date'],y=df['ave'])
plt.show()

# %%
df_1=df[df['Cluster'].isin([1])]
df_2=df[df['Cluster'].isin([2])]
df_3=df[df['Cluster'].isin([3])]

# %%
plt.scatter(x=df_1['Date'],y=df_1['ave'],c='y',marker='.')
plt.scatter(x=df_2['Date'],y=df_2['ave'],c='r',marker='.')
plt.scatter(x=df_3['Date'],y=df_3['ave'],c='b',marker='.')
plt.axhline(y=4.5, color='gray',linestyle='--')
plt.axhline(y=4.0, color='gray',linestyle='--')
plt.show()

# %%
df2=pd.read_excel("123.xlsx")
df2
# Out:
#      Contest number  Number of  reported results  Number in hard mode  \
# 0               202                        80630                 1362
# 1               203                       101503                 1763
# 2               204                        91477                 1913
# 3               205                       107134                 2242
# 4               206                       153880                 3017
# ..              ...                          ...                  ...
# 354             556                        20879                 2012
# 355             557                        20160                 1937
# 356             558                        20001                 1919
# 357             559                        21204                 1973
# 358             560                        20380                 1899
#
#         1 try   2 tries    3 tries    4 tries    5 tries    6 tries  \
# ...

# %%
df2_1 = df2[df2['Cluster'].isin([1])]
df2_2 = df2[df2['Cluster'].isin([2])]
df2_3 = df2[df2['Cluster'].isin([3])]
plt.scatter(x=df2_1['Case Number'], y=df2_1['ave'], c='y', marker='.')
plt.scatter(x=df2_2['Case Number'], y=df2_2['ave'], c='r', marker='.')
plt.scatter(x=df2_3['Case Number'], y=df2_3['ave'], c='b', marker='.')
plt.axhline(y=4.5, color='gray', linestyle='--')
plt.axhline(y=4.0, color='gray', linestyle='--')
plt.show()
